# %%
# opção 1: chamar main com argv explícito (usa defaults)
import copy_results_cycle_alias as cr
cr.main([])  # dry-run desativado; usa defaults

# opção 2: chamar a função run diretamente
from pathlib import Path
cr.run(Path("src/experiment_configs/OlD_Results_2/results"),
       Path("src/experiment_configs/results"),
       dry_run=True)
# Out:
# Planned copies (EXECUTE):
#   UNISIM_IV_P11_Seq2Context_cycle_1  ->  UNISIM_IV_P11_Seq2Context_cycle_4
#   UNISIM_IV_P11_Seq2Context_cycle_2  ->  UNISIM_IV_P11_Seq2Context_cycle_5
#   UNISIM_IV_P11_Seq2Context_cycle_3  ->  UNISIM_IV_P11_Seq2Context_cycle_6
#   UNISIM_IV_P11_Seq2PIN_cycle_1  ->  UNISIM_IV_P11_Seq2PIN_cycle_1
#   UNISIM_IV_P11_Seq2PIN_cycle_2  ->  UNISIM_IV_P11_Seq2PIN_cycle_2
#   UNISIM_IV_P11_Seq2PIN_cycle_3  ->  UNISIM_IV_P11_Seq2PIN_cycle_3
#   UNISIM_IV_P11_Seq2Trend_cycle_1  ->  UNISIM_IV_P11_Seq2Trend_cycle_2
#   UNISIM_IV_P11_Seq2Trend_cycle_2  ->  UNISIM_IV_P11_Seq2Trend_cycle_3
#   UNISIM_IV_P11_Seq2Trend_cycle_3  ->  UNISIM_IV_P11_Seq2Trend_cycle_4
#   UNISIM_IV_P12_Seq2Context_cycle_1  ->  UNISIM_IV_P12_Seq2Context_cycle_4
#   UNISIM_IV_P12_Seq2Context_cycle_2  ->  UNISIM_IV_P12_Seq2Context_cycle_5
#   UNISIM_IV_P12_Seq2Context_cycle_3  ->  UNISIM_IV_P12_Seq2Context_cycle_6
#   UNISIM_IV_P12_Seq2PIN_cycle_1  ->  UNISIM_IV_P12_Seq2PIN_cycle_1
# ...
